# %%
import pandas as pd
import numpy as np

file1 = pd.read_csv('file1.csv')
file1.head()

file2 = pd.read_csv('file2.csv')
file2.head()

file3 = pd.read_csv('file3.csv')
file3.head()

display(file1.head())
display(file2.head())
display(file3.head())
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file1 = file1.rename(columns={'Customer':'Customer Id','ST':'State','GENDER':'Gender'})
file1.head()
# Out:
#   Customer Id       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
#
#   Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                     NaN      0.0                1000.0
# 1              697953.59%      0.0                  94.0
# 2             1288743.17%  48767.0                 108.0
# 3              764586.18%      0.0                 106.0
# 4              536307.65%  36357.0                  68.0
#
#   Number of Open Complaints     Policy Type  Vehicle Class  Total Claim Amount
# 0                    1/0/00   Personal Auto  Four-Door Car            2.704934
# 1                    1/0/00   Personal Auto  Four-Door Car         1131.464935
# ...

# %%
file2 = file2.rename(columns={'Customer':'Customer Id','ST':'State','GENDER':'Gender'})
file1.head()
# Out:
#   Customer Id       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
#
#   Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                     NaN      0.0                1000.0
# 1              697953.59%      0.0                  94.0
# 2             1288743.17%  48767.0                 108.0
# 3              764586.18%      0.0                 106.0
# 4              536307.65%  36357.0                  68.0
#
#   Number of Open Complaints     Policy Type  Vehicle Class  Total Claim Amount
# 0                    1/0/00   Personal Auto  Four-Door Car            2.704934
# 1                    1/0/00   Personal Auto  Four-Door Car         1131.464935
# ...

# %%
file3 = file3.rename(columns={'Customer':'Customer Id'})
file3.head()
# Out:
#   Customer Id       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
#
#   Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0      M       0                   104                          0
# 1      M       0                    66                          0
# 2      F   25820                    82                          0
# 3      F       0                   121                          0
# 4      M   30366                   101                          2
#
#      Policy Type  Total Claim Amount  Vehicle Class
# 0  Personal Auto          499.200000   Two-Door Car
# ...

# %%
file1.columns
# Out:
# Index(['Customer Id', 'State', 'Gender', 'Education',
#        'Customer Lifetime Value', 'Income', 'Monthly Premium Auto',
#        'Number of Open Complaints', 'Policy Type', 'Vehicle Class',
#        'Total Claim Amount'],
#       dtype='object')

# %%
#'Customer Id', 'Gender', 'State','Customer Lifetime Value','Number of Open Complaints','Income', 'Policy Type','Monthly Premium Auto','Vehicle Class','Total Claim Amount','Education',]

# %%
file1 = file1[['Customer Id', 'Gender', 'State','Customer Lifetime Value','Number of Open Complaints','Income', 'Policy Type','Monthly Premium Auto','Vehicle Class','Total Claim Amount','Education',]]
file1.head()
# Out:
#   Customer Id Gender       State Customer Lifetime Value  \
# 0     RB50392    NaN  Washington                     NaN
# 1     QZ44356      F     Arizona              697953.59%
# 2     AI49188      F      Nevada             1288743.17%
# 3     WW63253      M  California              764586.18%
# 4     GA49547      M  Washington              536307.65%
#
#   Number of Open Complaints   Income     Policy Type  Monthly Premium Auto  \
# 0                    1/0/00      0.0   Personal Auto                1000.0
# 1                    1/0/00      0.0   Personal Auto                  94.0
# 2                    1/0/00  48767.0   Personal Auto                 108.0
# 3                    1/0/00      0.0  Corporate Auto                 106.0
# 4                    1/0/00  36357.0   Personal Auto                  68.0
#
#    Vehicle Class  Total Claim Amount             Education
# 0  Four-Door Car            2.704934                Master
# ...

# %%
file2 = file2[['Customer Id', 'Gender', 'State','Customer Lifetime Value','Number of Open Complaints','Income', 'Policy Type','Monthly Premium Auto','Vehicle Class','Total Claim Amount','Education',]]
file2.head()
# Out:
#   Customer Id Gender       State Customer Lifetime Value  \
# 0     GS98873      F     Arizona              323912.47%
# 1     CW49887      F  California              462680.11%
# 2     MY31220      F  California              899704.02%
# 3     UH35128      F      Oregon             2580706.30%
# 4     WH52799      F     Arizona              380812.21%
#
#   Number of Open Complaints  Income     Policy Type  Monthly Premium Auto  \
# 0                    1/0/00   16061   Personal Auto                    88
# 1                    1/0/00   79487    Special Auto                   114
# 2                    1/0/00   54230   Personal Auto                   112
# 3                    1/1/00   71210   Personal Auto                   214
# 4                    1/0/00   94903  Corporate Auto                    94
#
#    Vehicle Class  Total Claim Amount Education
# 0  Four-Door Car               633.6  Bachelor
# 1            SUV               547.2    Master
# ...

# %%
file3 = file3[['Customer Id', 'Gender', 'State','Customer Lifetime Value','Number of Open Complaints','Income', 'Policy Type','Monthly Premium Auto','Vehicle Class','Total Claim Amount','Education',]]
file3.head()
# Out:
#   Customer Id Gender       State  Customer Lifetime Value  \
# 0     SA25987      M  Washington              3479.137523
# 1     TB86706      M     Arizona              2502.637401
# 2     ZL73902      F      Nevada              3265.156348
# 3     KX23516      F  California              4455.843406
# 4     FN77294      M  California              7704.958480
#
#    Number of Open Complaints  Income    Policy Type  Monthly Premium Auto  \
# 0                          0       0  Personal Auto                   104
# 1                          0       0  Personal Auto                    66
# 2                          0   25820  Personal Auto                    82
# 3                          0       0  Personal Auto                   121
# 4                          2   30366  Personal Auto                   101
#
#    Vehicle Class  Total Claim Amount             Education
# 0   Two-Door Car          499.200000  High School or Below
# ...

# %%
#file2['Customer Lifetime Value'] = file2['Customer Lifetime Value'].str.rstrip("%").astype(float)/100
#file2.head()

# %%
file1['Customer Lifetime Value'] = file1['Customer Lifetime Value'].str.rstrip("%").astype(float)/100
file1.head()
# Out:
#   Customer Id Gender       State  Customer Lifetime Value  \
# 0     RB50392    NaN  Washington                      NaN
# 1     QZ44356      F     Arizona                6979.5359
# 2     AI49188      F      Nevada               12887.4317
# 3     WW63253      M  California                7645.8618
# 4     GA49547      M  Washington                5363.0765
#
#   Number of Open Complaints   Income     Policy Type  Monthly Premium Auto  \
# 0                    1/0/00      0.0   Personal Auto                1000.0
# 1                    1/0/00      0.0   Personal Auto                  94.0
# 2                    1/0/00  48767.0   Personal Auto                 108.0
# 3                    1/0/00      0.0  Corporate Auto                 106.0
# 4                    1/0/00  36357.0   Personal Auto                  68.0
#
#    Vehicle Class  Total Claim Amount             Education
# 0  Four-Door Car            2.704934                Master
# ...

# %%
file2['Customer Lifetime Value'] = file2['Customer Lifetime Value'].str.rstrip("%").astype(float)/100
file2.head()
# Out:
#   Customer Id       State Gender Education  Customer Lifetime Value  Income  \
# 0     GS98873     Arizona      F  Bachelor                3239.1247   16061
# 1     CW49887  California      F    Master                4626.8011   79487
# 2     MY31220  California      F   College                8997.0402   54230
# 3     UH35128      Oregon      F   College               25807.0630   71210
# 4     WH52799     Arizona      F   College                3808.1221   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# ...

# %%
print(file1.columns==file2.columns)
print(file2.columns==file3.columns)
print(file3.columns==file1.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True]
# [ True  True  True  True  True  True  True  True  True  True  True]

# %%
data = pd.concat([file1,file2,file3], axis = 0)
data.head()
# Out:
#   Customer Id Gender       State Customer Lifetime Value  \
# 0     RB50392    NaN  Washington                     NaN
# 1     QZ44356      F     Arizona               6979.5359
# 2     AI49188      F      Nevada              12887.4317
# 3     WW63253      M  California               7645.8618
# 4     GA49547      M  Washington               5363.0765
#
#   Number of Open Complaints   Income     Policy Type  Monthly Premium Auto  \
# 0                    1/0/00      0.0   Personal Auto                1000.0
# 1                    1/0/00      0.0   Personal Auto                  94.0
# 2                    1/0/00  48767.0   Personal Auto                 108.0
# 3                    1/0/00      0.0  Corporate Auto                 106.0
# 4                    1/0/00  36357.0   Personal Auto                  68.0
#
#    Vehicle Class  Total Claim Amount             Education
# 0  Four-Door Car            2.704934                Master
# ...

# %%
data.dtypes
# Out:
# Customer Id                   object
# Gender                        object
# State                         object
# Customer Lifetime Value       object
# Number of Open Complaints     object
# Income                       float64
# Policy Type                   object
# Monthly Premium Auto         float64
# Vehicle Class                 object
# Total Claim Amount           float64
# Education                     object
# dtype: object

# %%
data.select_dtypes(include=["float64"])
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
data.select_dtypes(include=["object"])
# Out:
#      Customer Id Gender       State Customer Lifetime Value  \
# 0        RB50392    NaN  Washington                     NaN
# 1        QZ44356      F     Arizona               6979.5359
# 2        AI49188      F      Nevada              12887.4317
# 3        WW63253      M  California               7645.8618
# 4        GA49547      M  Washington               5363.0765
# ...          ...    ...         ...                     ...
# 7065     LA72316      M  California             23405.98798
# 7066     PK87824      F  California             3096.511217
# 7067     TD14365      M  California             8163.890428
# 7068     UP19263      M  California             7524.442436
# 7069     Y167826      M  California             2611.836866
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# ...

# %%
#Delete the column education and the number of open complaints from the dataframe.

data = data.drop(['Education','Number of Open Complaints'], axis=1)
data.head()
# Out:
#   Customer Id Gender       State Customer Lifetime Value   Income  \
# 0     RB50392    NaN  Washington                     NaN      0.0
# 1     QZ44356      F     Arizona               6979.5359      0.0
# 2     AI49188      F      Nevada              12887.4317  48767.0
# 3     WW63253      M  California               7645.8618      0.0
# 4     GA49547      M  Washington               5363.0765  36357.0
#
#       Policy Type  Monthly Premium Auto  Vehicle Class  Total Claim Amount
# 0   Personal Auto                1000.0  Four-Door Car            2.704934
# 1   Personal Auto                  94.0  Four-Door Car         1131.464935
# 2   Personal Auto                 108.0   Two-Door Car          566.472247
# 3  Corporate Auto                 106.0            SUV          529.881344
# 4   Personal Auto                  68.0  Four-Door Car           17.269323

# %%
#Finding duplicate rows

duplicate = data[data.duplicated()]
 
print("Duplicate Rows :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
#      Customer Id Gender State Customer Lifetime Value  Income Policy Type  \
# 1072         NaN    NaN   NaN                     NaN     NaN         NaN
# 1073         NaN    NaN   NaN                     NaN     NaN         NaN
# 1074         NaN    NaN   NaN                     NaN     NaN         NaN
# 1075         NaN    NaN   NaN                     NaN     NaN         NaN
# 1076         NaN    NaN   NaN                     NaN     NaN         NaN
# ...          ...    ...   ...                     ...     ...         ...
# 4003         NaN    NaN   NaN                     NaN     NaN         NaN
# 4004         NaN    NaN   NaN                     NaN     NaN         NaN
# 4005         NaN    NaN   NaN                     NaN     NaN         NaN
# 4006         NaN    NaN   NaN                     NaN     NaN         NaN
# 4007         NaN    NaN   NaN                     NaN     NaN         NaN
#
#       Monthly Premium Auto Vehicle Class  Total Claim Amount
# ...

# %%
#Finding duplicate rows

bool_series = data.duplicated()
bool_series
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
#Deleting duplicate rows

data = data.drop_duplicates()
data.head()
# Out:
#   Customer Id Gender       State Customer Lifetime Value   Income  \
# 0     RB50392    NaN  Washington                     NaN      0.0
# 1     QZ44356      F     Arizona               6979.5359      0.0
# 2     AI49188      F      Nevada              12887.4317  48767.0
# 3     WW63253      M  California               7645.8618      0.0
# 4     GA49547      M  Washington               5363.0765  36357.0
#
#       Policy Type  Monthly Premium Auto  Vehicle Class  Total Claim Amount
# 0   Personal Auto                1000.0  Four-Door Car            2.704934
# 1   Personal Auto                  94.0  Four-Door Car         1131.464935
# 2   Personal Auto                 108.0   Two-Door Car          566.472247
# 3  Corporate Auto                 106.0            SUV          529.881344
# 4   Personal Auto                  68.0  Four-Door Car           17.269323

# %%
data.shape
# Out:
# (9138, 9)

# %%
#data filtering for customers who have an income of 0 or less

data = data[(data['Income'])> 0]
data
# Out:
#      Customer Id Gender       State Customer Lifetime Value   Income  \
# 2        AI49188      F      Nevada              12887.4317  48767.0
# 4        GA49547      M  Washington               5363.0765  36357.0
# 5        OC83172      F      Oregon               8256.2978  62902.0
# 6        XZ87318      F      Oregon               5380.8986  55350.0
# 8        DY87989      M      Oregon               24127.504  14072.0
# ...          ...    ...         ...                     ...      ...
# 7063     TF56202      M  California             5032.165498  66367.0
# 7064     YM19146      F  California             4100.398533  47761.0
# 7065     LA72316      M  California             23405.98798  71941.0
# 7066     PK87824      F  California             3096.511217  21604.0
# 7068     UP19263      M  California             7524.442436  21941.0
#
#          Policy Type  Monthly Premium Auto  Vehicle Class  Total Claim Amount
# ...

# %%
data1 = data.copy()
data1
# Out:
#      Customer Id Gender       State Customer Lifetime Value   Income  \
# 2        AI49188      F      Nevada              12887.4317  48767.0
# 4        GA49547      M  Washington               5363.0765  36357.0
# 5        OC83172      F      Oregon               8256.2978  62902.0
# 6        XZ87318      F      Oregon               5380.8986  55350.0
# 8        DY87989      M      Oregon               24127.504  14072.0
# ...          ...    ...         ...                     ...      ...
# 7063     TF56202      M  California             5032.165498  66367.0
# 7064     YM19146      F  California             4100.398533  47761.0
# 7065     LA72316      M  California             23405.98798  71941.0
# 7066     PK87824      F  California             3096.511217  21604.0
# 7068     UP19263      M  California             7524.442436  21941.0
#
#          Policy Type  Monthly Premium Auto  Vehicle Class  Total Claim Amount
# ...

# %%
# these are all the customers with income of more than 0.
data1['Customer Id']
data1
# Out:
#      Customer Id Gender       State Customer Lifetime Value   Income  \
# 2        AI49188      F      Nevada              12887.4317  48767.0
# 4        GA49547      M  Washington               5363.0765  36357.0
# 5        OC83172      F      Oregon               8256.2978  62902.0
# 6        XZ87318      F      Oregon               5380.8986  55350.0
# 8        DY87989      M      Oregon               24127.504  14072.0
# ...          ...    ...         ...                     ...      ...
# 7063     TF56202      M  California             5032.165498  66367.0
# 7064     YM19146      F  California             4100.398533  47761.0
# 7065     LA72316      M  California             23405.98798  71941.0
# 7066     PK87824      F  California             3096.511217  21604.0
# 7068     UP19263      M  California             7524.442436  21941.0
#
#          Policy Type  Monthly Premium Auto  Vehicle Class  Total Claim Amount
# ...
